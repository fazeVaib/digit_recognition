# %% [markdown]
# ## Digit Recognition from Image

# %%
import cv2 as cv
from sklearn.externals import joblib
from skimage.feature import hog
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
clf, preproc = joblib.load('mnist_clf_svm.pkl')

# %%
img = cv.imread('image3.jpg')

# %%
def show(image):
    plt.figure(figsize=(5, 5)) # size is in inches
    plt.axis('off')
    plt.imshow(image, interpolation='nearest', cmap='Greys_r') #nearest neighbour interpolation
    
show(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
im_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
im_gray = cv.GaussianBlur(im_gray, (5,5), 0)
show(im_gray)

# %%
rt, im_th = cv.threshold(im_gray, 120, 255, cv.THRESH_BINARY_INV)
show(im_th)

# %%
_, contours, hier = cv.findContours(im_th.copy(), cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
print(len(contours))
# Out:
# 10

# %%
rects = [cv.boundingRect(ctr) for ctr in contours]
print(rects)
# Out:
# [(316, 188, 90, 120), (43, 188, 90, 120), (420, 187, 97, 119), (223, 187, 82, 122), (139, 186, 83, 121), (79, 36, 34, 118), (400, 35, 71, 130), (305, 35, 84, 117), (132, 34, 78, 118), (224, 33, 73, 129)]

# %%
for rect in rects:
    cv.rectangle(img, (rect[0], rect[1]), (rect[0] + rect[2], rect[1] + rect[3]), (0, 255, 0), 2)
    leng = int(rect[3] * 1.6)
    pt1 = int(rect[1] + rect[3] // 2 - leng // 2)
    pt2 = int(rect[0] + rect[2] // 2 - leng // 2)
    roi = im_th[pt1:pt1+leng, pt2:pt2+leng]
    # Resize the image
    roi = cv.resize(roi, (28, 28), interpolation=cv.INTER_AREA)
    roi = cv.dilate(roi, (3, 3))
    # Calculate the HOG features
    roi_hog_fd = hog(roi, orientations=9, pixels_per_cell=(14, 14), cells_per_block=(1, 1), block_norm='L1')
    roi_hog_fd = preproc.transform(np.array([roi_hog_fd], 'float64'))
    # Pridict digit
    nbr = clf.predict(roi_hog_fd)
    cv.putText(img, str(int(nbr[0])), (rect[0], rect[1]),cv.FONT_HERSHEY_DUPLEX, 1, (255, 0, 0), 1)
    
show(img)
# Out:
# /home/darkghost/anaconda3/envs/MLenv/lib/python3.6/site-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-c430c3a8d832> in <module>()
#       6     roi = im_th[pt1:pt1+leng, pt2:pt2+leng]
#       7     # Resize the image
# ----> 8     roi = cv.resize(roi, (28, 28), interpolation=cv.INTER_AREA)
#       9     roi = cv.dilate(roi, (3, 3))
#      10     # Calculate the HOG features
#
# error: /home/travis/miniconda/conda-bld/conda_1486587069159/work/opencv-3.1.0/modules/imgproc/src/imgwarp.cpp:3229: error: (-215) ssize.area() > 0 in function resize
